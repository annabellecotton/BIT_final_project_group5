# %% [markdown]
# Toby Mast
# CMINFO 0010
# Final Project

# %%
#import permit data from wrpdc
import pandas as pd
import numpy as np

permit_data = pd.read_csv("Permits.csv",index_col="id")
permit_data.dropna()
count = permit_data['neighborhood'].value_counts() 
count[count > 10]
print(count)
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']

count[count>10].plot.bar()
# Out:
# Squirrel Hill North    92
# Highland Park          49
# Shadyside              43
# Homewood North         40
# Squirrel Hill South    40
#                        ..
# West End                1
# Spring Garden           1
# Allegheny Center        1
# Central Oakland         1
# Lincoln Place           1
# Name: neighborhood, Length: 73, dtype: int64

# %%
pie_chart = count[count>10].plot.pie()
